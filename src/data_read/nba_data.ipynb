# %% [markdown]
# ## NBA MVP Prediction Project

# %%
# Install dependencies
from consolidate_data import consolidate_data

df = consolidate_data()
df.head()
# Out:
# d:\Projects\Data Science Projects\nba_mvp_prediction\src\data_read\extract_data.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   mvp_dataframe = pd.read_html(str(mvp_table))[0]
# d:\Projects\Data Science Projects\nba_mvp_prediction\src\data_read\extract_data.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   mvp_dataframe = pd.read_html(str(mvp_table))[0]
# d:\Projects\Data Science Projects\nba_mvp_prediction\src\data_read\extract_data.py:59: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   mvp_dataframe = pd.read_html(str(mvp_table))[0]
# ...
